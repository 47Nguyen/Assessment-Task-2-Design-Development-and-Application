# %% [markdown]
# ## ASM 2

# %%
import pandas as pd
import numpy as np

# %%
## Load datasets
test_data_path = r"A2_FashionDataset\FashionDataset\test\styles_prediction.csv" #relatvie path
train_data_path =  r"A2_FashionDataset\FashionDataset\train\styles_train.csv" # relative path

# %%
train_data = pd.read_csv(train_data_path)
test_data = pd.read_csv(test_data_path)

# %%
train_data.head()
test_data.head()
# Out:
#       id  gender  articleType  season  usage
# 0  52003     NaN          NaN     NaN    NaN
# 1  52007     NaN          NaN     NaN    NaN
# 2  52017     NaN          NaN     NaN    NaN
# 3  52021     NaN          NaN     NaN    NaN
# 4  52023     NaN          NaN     NaN    NaN
